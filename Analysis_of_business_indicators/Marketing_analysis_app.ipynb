# %% [markdown]
# <h1 align="center" style="color:#8B4513">
#     Анализ бизнес-показателей
#     </h1>

# %% [markdown]
# **Описание проекта**
# Маркетинговый анализ развлекательного приложения Procrastinate Pro+. Несмотря на огромные вложения в рекламу, последние несколько месяцев компания терпит убытки.
# **Задача** — разобраться в причинах и помочь компании выйти в плюс.
#
# Есть данные о пользователях, привлечённых с 1 мая по 27 октября 2019 года:
# - лог сервера с данными об их посещениях,
# - выгрузка их покупок за этот период,
# - рекламные расходы.
#
# **Необходимо изучить:**
# - откуда приходят пользователи и какими устройствами они пользуются
# - сколько стоит привлечение пользователей из различных рекламных каналов
# - сколько денег приносит каждый клиент
# - когда расходы на привлечение клиента окупаются
# - какие факторы мешают привлечению клиентов

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-и-изучение-данных" data-toc-modified-id="Загрузка-и-изучение-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка и изучение данных</a></span><ul class="toc-item"><li><span><a href="#Приведение-типов-данных" data-toc-modified-id="Приведение-типов-данных-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Приведение типов данных</a></span></li><li><span><a href="#Обработка-дупликатов" data-toc-modified-id="Обработка-дупликатов-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Обработка дупликатов</a></span></li></ul></li><li><span><a href="#Функции-для-расчета-удержания,-конверсии,-LTV,-ROI" data-toc-modified-id="Функции-для-расчета-удержания,-конверсии,-LTV,-ROI-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Функции для расчета удержания, конверсии, LTV, ROI</a></span><ul class="toc-item"><li><span><a href="#функция-для-создания-пользовательских-профилей" data-toc-modified-id="функция-для-создания-пользовательских-профилей-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>функция для создания пользовательских профилей</a></span></li><li><span><a href="#функция-для-расчёта-удержания" data-toc-modified-id="функция-для-расчёта-удержания-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>функция для расчёта удержания</a></span></li><li><span><a href="#функция-для-расчёта-конверсии" data-toc-modified-id="функция-для-расчёта-конверсии-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>функция для расчёта конверсии</a></span></li><li><span><a href="#функция-для-расчёта-LTV-и-ROI" data-toc-modified-id="функция-для-расчёта-LTV-и-ROI-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>функция для расчёта LTV и ROI</a></span></li><li><span><a href="#функция-для-сглаживания-фрейма" data-toc-modified-id="функция-для-сглаживания-фрейма-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>функция для сглаживания фрейма</a></span></li><li><span><a href="#функция-для-визуализации-удержания" data-toc-modified-id="функция-для-визуализации-удержания-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>функция для визуализации удержания</a></span></li><li><span><a href="#функция-для-визуализации-конверсии" data-toc-modified-id="функция-для-визуализации-конверсии-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>функция для визуализации конверсии</a></span></li><li><span><a href="#функция-для-визуализации-LTV-и-ROI" data-toc-modified-id="функция-для-визуализации-LTV-и-ROI-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>функция для визуализации LTV и ROI</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span></li><li><span><a href="#Маркетинговый-анализ-данных" data-toc-modified-id="Маркетинговый-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Маркетинговый анализ данных</a></span><ul class="toc-item"><li><span><a href="#Траты-на-маркетинг" data-toc-modified-id="Траты-на-маркетинг-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Траты на маркетинг</a></span></li><li><span><a href="#Общая-окупаемость-рекламы" data-toc-modified-id="Общая-окупаемость-рекламы-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Общая окупаемость рекламы</a></span></li><li><span><a href="#Окупаемость-рекламы-по-каналам" data-toc-modified-id="Окупаемость-рекламы-по-каналам-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Окупаемость рекламы по каналам</a></span></li><li><span><a href="#Окупаемость-рекламы-по-странам" data-toc-modified-id="Окупаемость-рекламы-по-странам-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Окупаемость рекламы по странам</a></span></li><li><span><a href="#Окупаемость-по-устройствам" data-toc-modified-id="Окупаемость-по-устройствам-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Окупаемость по устройствам</a></span></li><li><span><a href="#Конверсия-и-удержание-пользователей" data-toc-modified-id="Конверсия-и-удержание-пользователей-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Конверсия и удержание пользователей</a></span><ul class="toc-item"><li><span><a href="#По-устройствам" data-toc-modified-id="По-устройствам-4.6.1"><span class="toc-item-num">4.6.1&nbsp;&nbsp;</span>По устройствам</a></span></li><li><span><a href="#По-странам" data-toc-modified-id="По-странам-4.6.2"><span class="toc-item-num">4.6.2&nbsp;&nbsp;</span>По странам</a></span></li><li><span><a href="#По-каналам" data-toc-modified-id="По-каналам-4.6.3"><span class="toc-item-num">4.6.3&nbsp;&nbsp;</span>По каналам</a></span></li></ul></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from datetime import datetime, timedelta

# %%
plt.rcParams['figure.figsize'] = [10, 4]
pd.set_option('display.float_format', '{:,.3f}'.format)

# %% [markdown]
# ## Загрузка и изучение данных

# %%
display(visits.head())
display(orders.head())
costs.head()
# Out:
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52    4.990
# 1  174361394180  2019-05-01 12:24:04    4.990
# 2  529610067795  2019-05-01 11:34:04    4.990
# 3  319939546352  2019-05-01 15:34:40    4.990
# 4  366000285810  2019-05-01 13:59:51    4.990
#            dt   Channel   costs
# 0  2019-05-01  FaceBoom 113.300
# 1  2019-05-02  FaceBoom  78.100
# ...

# %% [markdown]
# **Описание данных**:
#
# Структура *visits_info_short.csv*:
#
# - `User Id` — уникальный идентификатор пользователя,
# - `Region` — страна пользователя,
# - `Device` — тип устройства пользователя,
# - `Channel` — идентификатор источника перехода,
# - `Session Start` — дата и время начала сессии,
# - `Session End` — дата и время окончания сессии.
#
# Структура *orders_info_short.csv*:
#
# - `User Id` — уникальный идентификатор пользователя,
# - `Event Dt` — дата и время покупки,
# - `Revenue` — сумма заказа.
#
# Структура *costs_info_short.csv*:
#
# - `Channel` — идентификатор рекламного источника,
# - `Dt` — дата проведения рекламной кампании,
# - `Costs` — расходы на эту кампанию.

# %% [markdown]
# Для удобства сразу переименуем клонки в таблицах

# %%
visits.columns = visits.columns.str.lower().str.replace(' ', '_')
orders.columns = orders.columns.str.lower().str.replace(' ', '_')
costs.columns = costs.columns.str.lower().str.replace(' ', '_')

# %%
display(visits.info())
display(orders.info())
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  object
#  5   session_end    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   40212 non-null  int64
#  1   event_dt  40212 non-null  object
#  2   revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# ...

# %% [markdown]
# ### Приведение типов данных
#
# Необходимо привести колонки с датами к типу *datetime*, остальные колонки в норме

# %%
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])
orders['event_dt'] = pd.to_datetime(orders['event_dt'])
costs['dt'] = pd.to_datetime(costs['dt']).dt.date

# %% [markdown]
# ### Обработка дупликатов
#
# Чтобы увидеть неявные дупликаты, нужно проверить уникальные значения в колонках со строковыми типами данных.

# %%
visits['region'].unique()
# Out:
# array(['United States', 'UK', 'France', 'Germany'], dtype=object)

# %%
visits['device'].unique()
# Out:
# array(['iPhone', 'Mac', 'Android', 'PC'], dtype=object)

# %%
visits['channel'].unique()
# Out:
# array(['organic', 'TipTop', 'RocketSuperAds', 'YRabbit', 'FaceBoom',
#        'MediaTornado', 'AdNonSense', 'LeapBob', 'WahooNetBanner',
#        'OppleCreativeMedia', 'lambdaMediaAds'], dtype=object)

# %%
costs['channel'].unique()
# Out:
# array(['FaceBoom', 'MediaTornado', 'RocketSuperAds', 'TipTop', 'YRabbit',
#        'AdNonSense', 'LeapBob', 'OppleCreativeMedia', 'WahooNetBanner',
#        'lambdaMediaAds'], dtype=object)

# %% [markdown]
# В названиях все нормально, можно проверить на повторы

# %%
visits.duplicated().sum()
# Out:
# 0

# %%
orders.duplicated().sum()
# Out:
# 0

# %%
costs.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Проверим на аномалии - отрицательные значения, нули - в данных о покупках и ценах

# %%
orders['revenue'].describe()
# Out:
# count   40,212.000
# mean         5.371
# std          3.454
# min          4.990
# 25%          4.990
# 50%          4.990
# 75%          4.990
# max         49.990
# Name: revenue, dtype: float64

# %%
costs['costs'].describe()
# Out:
# count   1,800.000
# mean       58.610
# std       107.740
# min         0.800
# 25%         6.495
# 50%        12.285
# 75%        33.600
# max       630.000
# Name: costs, dtype: float64

# %% [markdown]
# В численных данных ошибок не видно. Также проверим временные данные на ошибки: интервалы

# %% [markdown]
# **Вывод**
#
# Данные подготовлены: типы приведены, дупликатов нет - можно продолжить исследование.

# %% [markdown]
# ## Функции для расчета удержания, конверсии, LTV, ROI

# %% [markdown]
# В начале создадим функции для анализа: создание пользовательских профилей, расчетов удержания, конверсии, LTV, ROI, построение графиков по этим метрикам и функция применения скользящего среднего для сглаживания графиков.
#
# ### функция для создания пользовательских профилей

# %%
def get_profiles(sessions, orders, events, ad_costs, event_names=[]):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # добавляем флаги для всех событий из event_names
    for event in event_names:
        if event in events['event_name'].unique():
            profiles[event] = profiles['user_id'].isin(
                events.query('event_name == @event')['user_id'].unique()
            )

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# ### функция для расчёта удержания

# %%
def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### функция для расчёта конверсии

# %%
def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### функция для расчёта LTV и ROI

# %%
def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# ### функция для сглаживания фрейма

# %%
def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# ### функция для визуализации удержания

# %%
def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2, legend=False
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4, legend=False)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### функция для визуализации конверсии

# %%
def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2, legend=False)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### функция для визуализации LTV и ROI

# %%
def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend(fontsize=15)
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2, legend=False)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3, legend=False)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend(fontsize=15)
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5, legend=False)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# Получим данные о пользовательских профилях

# %%
events = None
profiles = get_profiles(visits, orders, events, costs)
profiles.head()
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True             1.088
# 1  2019-07-09 2019-07-01  False             1.107
# 2  2019-10-01 2019-10-01  False             0.000
# 3  2019-08-22 2019-08-01  False             0.988
# 4  2019-10-02 2019-10-01  False             0.231

# %%
print(f"""
Самая ранняя дата привлечения пользователля {profiles['first_ts'].min()}
Самая поздняя дата привлечения пользователля {profiles['first_ts'].max()}
""")
# Out:
# Самая ранняя дата привлечения пользователля 2019-05-01 00:00:41
# Самая поздняя дата привлечения пользователля 2019-10-27 23:59:04

# %% [markdown]
# Для исследования создана функция, принимающая таблицу с профилями пользователей и название колонки, по которой группируются данные, и возвращающую таблицу с количеством уникальных пользователей в группе и долю, платящих пользователей в этой группе

# %%
def research_profiles(df, col):
    prof_reg = df.groupby(col).agg({'user_id': 'nunique'})
    prof_reg = prof_reg.merge(df.query('payer == True').groupby(col)
                                .agg({'user_id': 'count'}), on=col, how='left')
    prof_reg.columns = ['count_all', 'count_payer']
    prof_reg['ratio_payer'] = prof_reg['count_payer'] / prof_reg['count_all']
    return (prof_reg.sort_values(by='ratio_payer', ascending=False)
            .style
            .background_gradient('Oranges', high=0.5, low=0.9)
            .format({'ratio_payer': '{:.2%}'}))

# %% [markdown]
# По странам

# %%
research_profiles(profiles, 'region')
# Out:
# <style  type="text/css" >
# #T_4644c_row0_col0,#T_4644c_row0_col1,#T_4644c_row0_col2{
#             background-color:  #c84202;
#             color:  #f1f1f1;
#         }#T_4644c_row1_col0,#T_4644c_row1_col1,#T_4644c_row3_col1,#T_4644c_row3_col2{
#             background-color:  #fdae6a;
#             color:  #000000;
#         }#T_4644c_row1_col2{
#             background-color:  #fda35c;
#             color:  #000000;
#         }#T_4644c_row2_col0,#T_4644c_row3_col0{
#             background-color:  #fdab66;
#             color:  #000000;
#         }#T_4644c_row2_col1{
#             background-color:  #fdad69;
#             color:  #000000;
#         }#T_4644c_row2_col2{
#             background-color:  #fda762;
#             color:  #000000;
# ...

# %% [markdown]
# По устройствам

# %%
research_profiles(profiles, 'device')
# Out:
# <style  type="text/css" >
# #T_1a90f_row0_col0{
#             background-color:  #fdaf6c;
#             color:  #000000;
#         }#T_1a90f_row0_col1,#T_1a90f_row2_col0{
#             background-color:  #fd984b;
#             color:  #000000;
#         }#T_1a90f_row0_col2,#T_1a90f_row1_col0,#T_1a90f_row1_col1{
#             background-color:  #c84202;
#             color:  #f1f1f1;
#         }#T_1a90f_row1_col2{
#             background-color:  #db4a02;
#             color:  #f1f1f1;
#         }#T_1a90f_row2_col1{
#             background-color:  #fd9040;
#             color:  #000000;
#         }#T_1a90f_row2_col2{
#             background-color:  #f06712;
#             color:  #000000;
#         }#T_1a90f_row3_col0{
#             background-color:  #fdad69;
#             color:  #000000;
#         }#T_1a90f_row3_col1,#T_1a90f_row3_col2{
#             background-color:  #fdae6a;
#             color:  #000000;
# ...

# %% [markdown]
# По рекламным каналам

# %%
research_profiles(profiles, 'channel')
# Out:
# <style  type="text/css" >
# #T_8b892_row0_col0{
#             background-color:  #f57520;
#             color:  #000000;
#         }#T_8b892_row0_col1,#T_8b892_row0_col2,#T_8b892_row10_col0{
#             background-color:  #c84202;
#             color:  #f1f1f1;
#         }#T_8b892_row1_col0,#T_8b892_row8_col1{
#             background-color:  #fdab66;
#             color:  #000000;
#         }#T_8b892_row1_col1{
#             background-color:  #fda55f;
#             color:  #000000;
#         }#T_8b892_row1_col2{
#             background-color:  #d64701;
#             color:  #f1f1f1;
#         }#T_8b892_row2_col0,#T_8b892_row6_col1,#T_8b892_row7_col1{
#             background-color:  #fdae6a;
#             color:  #000000;
#         }#T_8b892_row2_col1,#T_8b892_row9_col1{
#             background-color:  #fdac67;
#             color:  #000000;
#         }#T_8b892_row2_col2{
#             background-color:  #de5005;
#             color:  #f1f1f1;
# ...

# %% [markdown]
# **Вывод**
#
# Данным приложением пользуются граждане США, Англии, Франции и Германии, больше всего пользователей, в том числе платящих, из Америки, в остальных странах, примерно одинаковые значения.
# В приложение заходят с iPhone, Android, PC и Mac, больше всего пользователей заходят с iPhone, а платящих - с Mac и iPhone.
# Больше всего пользователей приходят сами по себе, а среди каналов привлечения популярен FaceBoom, зато большинство платящих приходят с каналов FaceBoom, AdNonSense, lambdaMediaAds и TipTop.

# %% [markdown]
# ## Маркетинговый анализ данных
#
# ### Траты на маркетинг

# %%
print(f'Общие траты на маркетинг с {costs["dt"].min()} по {costs["dt"].max()} составили {costs["costs"].sum():.0f}')
# Out:
# Общие траты на маркетинг с 2019-05-01 по 2019-10-27 составили 105497

# %%
plt.figure(figsize=(15, 10))
payment_for_channel = (costs.groupby('channel')
                            .agg({'costs': 'sum'})
                            .sort_values(by='costs', ascending=False))
payment_for_channel.plot(kind='bar', rot=15,
                         ax=plt.subplot(2, 1, 1), grid=True)
[plt.text(i, v, f'{v:.0f}', fontsize=13) for i, v in enumerate(payment_for_channel['costs'])]
plt.title('Траты по каналам привлечения покупателей', fontsize=15)

(costs.pivot_table(index='dt', columns='channel', values='costs', aggfunc='sum')
 .plot(ax=plt.subplot(2, 1, 2), grid=True))
plt.title('Изменение трат по каналам со временем', fontsize=15)


plt.legend(fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# Для расчета средней стоимости привлечения пользователей, надо таблицу с профилями сортировать по времени и удалить дупликаты пользователей, оставив первое вхождение, а затем взять среднюю стоимость.

# %%
print('Средняя стоимость привлечения одного клиента:')
(profiles
 .query('channel != "organic"')
 .sort_values(by='dt')
 .drop_duplicates(subset='user_id', keep='first')['acquisition_cost'].mean())
# Out:
# Средняя стоимость привлечения одного клиента:
# 1.127481323942759

# %%
print('Средняя стоимость привлечения одного клиента по каналам:')
(profiles
 .query('channel != "organic"')
 .sort_values(by='dt')
 .drop_duplicates(subset='user_id', keep='first')
 .groupby('channel')
 .agg({'acquisition_cost': 'mean'})
 .sort_values(by='acquisition_cost', ascending=False)
 .style.background_gradient('Oranges'))
# Out:
# Средняя стоимость привлечения одного клиента по каналам:
# <style  type="text/css" >
# #T_ed71c_row0_col0{
#             background-color:  #7f2704;
#             color:  #f1f1f1;
#         }#T_ed71c_row1_col0{
#             background-color:  #fdb576;
#             color:  #000000;
#         }#T_ed71c_row2_col0{
#             background-color:  #fdc189;
#             color:  #000000;
#         }#T_ed71c_row3_col0{
#             background-color:  #fdd9b5;
#             color:  #000000;
#         }#T_ed71c_row4_col0{
#             background-color:  #fee2c6;
#             color:  #000000;
#         }#T_ed71c_row5_col0{
#             background-color:  #feecda;
#             color:  #000000;
#         }#T_ed71c_row6_col0{
#             background-color:  #fff4e8;
#             color:  #000000;
#         }#T_ed71c_row7_col0,#T_ed71c_row8_col0,#T_ed71c_row9_col0{
#             background-color:  #fff5eb;
#             color:  #000000;
# ...

# %% [markdown]
# **Вывод**
#
# Самые большие траты приходятся на каналы TipTop и FaceBoom, по ним же и растут расходы со временем, на другие каналы тратится стабильное количество денег. В среднем на привлечение одного пользователя тратится около 1,13 ед., по этому значению лидируют также TipTop и FaceBoom. Увеличивать инвестиции в эти каналы, возможно, плохая идея, т.к. с ростом средней стоимости привлечения и суммой инвестиций в канал количество новых клиентов растет медленнее или даже снижается.

# %% [markdown]
# ### Общая окупаемость рекламы

# %% [markdown]
# Сначала установим дату анализа - 1 ноября 2019 и горизонт анализа - 2 недели, а также исключим органических пользователей, т.к. явного отношения к рекламе они не имеют.

# %%
observation_date = pd.to_datetime('2019, 11, 1', format='%Y, %m, %d')
horizont = 14
profiles = profiles.query('channel != "organic"')

# %% [markdown]
# Теперь можно получить сырые данные, LTV, ROI и их динамики по общей окупаемости рекламы, и построим графики.

# %%
total_row, total_ltv, total_ltv_in_time, total_roi, total_roi_in_time = get_ltv(
    profiles, orders, observation_date, horizont)

# %%
plot_ltv_roi(total_ltv, total_ltv_in_time, total_roi,
             total_roi_in_time, horizont, window=5)

# %% [markdown]
# **Вывод**
#
# За две недели реклама не окупается, в конце мая резко повышается стоимость привлечения пользователей и далее только растет, окупаемость инвестиций падает с мая, особенно резкое падение было в мае, а с июня не превышает уровень окупаемости.
# LTV с мая по октябрь стабильна, хотя и колеблется в течении месяца, т.е. отношение пользователей к приложению стабильно, при этом траты на рекламу растут и соответственно окупаемость инвестиций падает.

# %% [markdown]
# ### Окупаемость рекламы по каналам

# %%
channel_row, channel_ltv, channel_ltv_in_time, channel_roi, channel_roi_in_time = get_ltv(
    profiles, orders, observation_date, horizont, dimensions=['channel'])

# %%
plot_ltv_roi(channel_ltv, channel_ltv_in_time, channel_roi,
             channel_roi_in_time, horizont, window=10)

# %% [markdown]
# **Вывод**
#
# Самые худшие каналы привлечения - TipTop и FaceBoom: инвестиции в эти каналы растут, стоимость привлечения пользователей растет у TipTop, у FaceBoom стабилен, но выше, чем у других каналов; инвестиции в эти каналы не окупаются за все время. Как и у других каналов, LTV стабилен за весь период, т.е. TipTop и FaceBoom не привлекает лучших пользователей.
# Лучший среди всех каналов - lambdaMediaAds: больше всего LTV, стабильный САС и ROI.
# САС у TipTop похож на САС из радела 4.2 и инвестиции в этот канал растут в 6 раз от мая к октябрю, пока эти инвестиции - основная причина проблем приложения.

# %% [markdown]
# ### Окупаемость рекламы по странам

# %%
country_row, country_ltv, country_ltv_in_time, country_roi, country_roi_in_time = get_ltv(
    profiles, orders, observation_date, horizont, dimensions=['region'])

# %%
plot_ltv_roi(country_ltv, country_ltv_in_time,
             country_roi, country_roi_in_time, horizont, window=10)

# %% [markdown]
# **Вывод**
#
# США - проблемная страна: хоть и лучшие показатели LTV, но САС растет, а у других стран даже снизилось в июне, американцы не окупаются совсем с середины мая, а вот пользователи из Франции, Германии и Англии окупаются уже на 6 день пользования приложением.

# %% [markdown]
# ### Окупаемость по устройствам

# %%
device_row, device_ltv, device_ltv_in_time, device_roi, device_roi_in_time = get_ltv(
    profiles, orders, observation_date, horizont, dimensions=['device'])

# %%
plot_ltv_roi(device_ltv, device_ltv_in_time,
             device_roi, device_roi_in_time, horizont, window=10)

# %% [markdown]
# **Вывод**
#
# Хуже всего дела на МАС и iPhone, а PC даже окупается в трех месяцах из 6, остальные устройства не окупаются с конца июня.
#
# Итого, неоправданный рост инвестиций в каналы TipTop и FaceBoom, хотя лучших клиентов они не приносят, пробдемы надо искать в данных по США, а устройства, возможно, не виноваты, т.к. их LTV стабильно с мая по октябрь.

# %% [markdown]
# ### Конверсия и удержание пользователей

# %% [markdown]
# #### По устройствам
#
# Построим конверсию по устройствам

# %%
konv_dev_raw, konv_dev_grouped, konv_dev_time = get_conversion(
    profiles, orders, observation_date, horizont, dimensions=['device'])

# %%
plot_conversion(konv_dev_grouped, konv_dev_time, horizont, window=10)

# %% [markdown]
# Конверсия на устройствах Android, Mac и iPhone, примерно, стабильна и колблется между 6 и 10 процентами за весь период, хуже конверсия на PC и ее динамика падает на несколько процентв к октябрю.
# Посмотрим на удержание.

# %%
reten_dev_raw, reten_dev_grouped, reten_dev_time = get_retention(
    profiles, visits, observation_date, horizont, dimensions=['device'])

# %%
plot_retention(reten_dev_grouped, reten_dev_time, horizont, window=10)

# %% [markdown]
# Удержание на всех устройствах, примерно, одинаково, динамика 14 дня имеет большие колебания и стабилизируется к концу периода, но явных отличий между устройствами нет.

# %% [markdown]
# #### По странам

# %%
konv_reg_raw, konv_reg_grouped, konv_reg_time = get_conversion(
    profiles, orders, observation_date, horizont, dimensions=['region'])

# %%
plot_conversion(konv_reg_grouped, konv_reg_time, horizont, window=10)

# %%
reten_reg_raw, reten_reg_grouped, reten_reg_time = get_retention(
    profiles, visits, observation_date, horizont, dimensions=['region'])

# %%
plot_retention(reten_reg_grouped, reten_reg_time, horizont, window=10)

# %% [markdown]
# Конверсия лучше у американцев, но удержание хуже по сравнению с другими странами. Особенностей в динамике нет, только американская конврсия немного улучшилась с июня, у европейцев колебания большие, поэтому точно сказать о динамике нельзя.

# %% [markdown]
# #### По каналам

# %%
konv_chan_raw, konv_chan_grouped, konv_chan_time = get_conversion(
    profiles, orders, observation_date, horizont, dimensions=['channel'])

# %%
plot_conversion(konv_chan_grouped, konv_chan_time, horizont, window=20)

# %%
reten_chan_raw, reten_chan_grouped, reten_chan_time = get_retention(
    profiles, visits, observation_date, horizont, dimensions=['channel'])

# %%
plot_retention(reten_chan_grouped, reten_chan_time, horizont, window=10)

# %% [markdown]
# Конвертация у FaceBoom и TipTop одна из лучших среди этих каналов, но удержание платящих пользователей худшее и динамика удержания 14 дня стабильно худшее - около нуля.

# %% [markdown]
# Посмотрим на доли , которые занимают рекламные компании в США и число привлеченных клиентов разными каналами по странам

# %%
ch_usa = (profiles.query('region == "United States"')
          .groupby(['channel']).agg({'user_id': 'nunique'}))
ch_usa['%'] = ch_usa['user_id'] / sum(ch_usa['user_id']) * 100
ch_usa.sort_values(by='%', ascending=False).style.background_gradient('Oranges')
# Out:
# <style  type="text/css" >
# #T_9d863_row0_col0,#T_9d863_row0_col1{
#             background-color:  #7f2704;
#             color:  #f1f1f1;
#         }#T_9d863_row1_col0,#T_9d863_row1_col1{
#             background-color:  #f26c16;
#             color:  #000000;
#         }#T_9d863_row2_col0,#T_9d863_row2_col1{
#             background-color:  #fff5ea;
#             color:  #000000;
#         }#T_9d863_row3_col0,#T_9d863_row3_col1,#T_9d863_row4_col0,#T_9d863_row4_col1{
#             background-color:  #fff5eb;
#             color:  #000000;
#         }</style><table id="T_9d863_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >user_id</th>        <th class="col_heading level0 col1" >%</th>    </tr>    <tr>        <th class="index_name level0" >channel</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
profiles.groupby(['channel', 'region']).agg({'user_id': 'nunique'})
# Out:
#                                   user_id
# channel            region
# AdNonSense         France            1366
#                    Germany           1219
#                    UK                1295
# FaceBoom           United States    29144
# LeapBob            France            2988
#                    Germany           2519
#                    UK                3046
# MediaTornado       United States     4364
# OppleCreativeMedia France            2991
#                    Germany           2562
#                    UK                3052
# RocketSuperAds     United States     4448
# TipTop             United States    19561
# WahooNetBanner     France            2971
#                    Germany           2579
#                    UK                3003
# YRabbit            United States     4312
# lambdaMediaAds     France             742
#                    Germany            649
#                    UK                 758

# %% [markdown]
# Для европейцев и американских пользователей работают разные каналы привлечения. У американцев - это YRabbit, RocketSuperAds	, MediaTornado, FaceBoom и TipTop, последние две из которых существенно лидируют, поэтому они и влияют сильно на маркетинг в США.
# Посмотрим на удержание, конвесию и окупаемость только в США.

# %%
profiles_amer = profiles.query('region == "United States"')
reten_amer_raw, reten_amer_grouped, reten_amer_time = get_retention(
    profiles_amer, visits.query('region == "United States"'),
    observation_date, horizont, dimensions=['channel'])
plot_retention(reten_amer_grouped, reten_amer_time, horizont, window=10)

# %%
konv_amer_raw, konv_amer_grouped, konv_amer_time = get_conversion(
    profiles_amer, orders, observation_date, horizont, dimensions=['channel'])
plot_conversion(konv_amer_grouped, konv_amer_time, horizont, window=20)

# %%
ch_amer_row, ch_amer_ltv, ch_amer_ltv_in_time, ch_amer_roi, ch_amer_roi_in_time = get_ltv(
    profiles_amer, orders, observation_date, horizont, dimensions=['channel'])
plot_ltv_roi(ch_amer_ltv, ch_amer_ltv_in_time,
             ch_amer_roi, ch_amer_roi_in_time, horizont, window=10)

# %% [markdown]
# От инвестиций в FaceBoom можно отказаться: клиенты с этого канала не удерживаются и не окупаются. В TipTop инвестиции стоит снизить до уровня начала мая, когда они окупались.

# %% [markdown]
# **Вывод**
#
# Реклама не окупается, и хоть в мае она окупалась, но уже тогда показатели летели вниз.
# Окупаемость хуже у устройств Apple в США у пользователей, приходящим по каналам FaceBoom и TipTop, при этом они конвертируются в покупателей лучше, по сравнению с другими каналами, но удерживаются хуже. Другими словами, динамика инвестиций в каналы FaceBoom и TipTop выросли в несколько раз за 6 месяцев, а привлекают они "слабых" клиентов, которые купили несколько раз и ушли.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# В приложение Procrastinate Pro+ приходят из США, Франции, Германии и Англии, причем американцев две трети от всех пользователей, примерно 7% американцев платящие, а платящих европейцев почти 4%, пользуются они устройствами РС, Мас, iPhone и Android, 36% из которых приходится на iPhone и по 20% на остальные устройства.
#
# Средняя стоимость привлечения клиента стоит 1,12 ед., а самый дорогой канал - TipTop, клиент с этого канала стоит примерно 2,8 ед.
#
# Окупаются европейцы, приходящие со всех каналов, кроме FaceBoom, TipTop и AdNonSense, но их доля небольшая, поэтому по общим показателям реклама не окупается.
#
# Основная проблема низкой окупаемости - это большие траты на привлечение пользователей по каналам FaceBoom и TipTop, где за 6 месяцев было потрачено 32 тыс и 55 тыс соответственно, тогда как по другим каналам составило 5 тыс и менее. Пользователи пришедшие по этим двум каналам имеют худшие показатели: тратят меньше всего денег и не окупаются совсем, удержание самое низкое - уже на 10 день почти все уходят, хотя у этих клиентов одна из лучших конверсий.
#
# Отделу маркетинга стоит пересмотреть инвестиционные планы, и не вкладывать большие средства в один-два канала привлечения пользователей, а распределять их между всеми каналами и открывать новые.

# %% [markdown]
# Хорошие показатели на американском рынке у каналов RocketSuperAds - третье место по доли платящих, после FaceBoom и TipTop.
# А на европейском рынке - lambdaMediaAds: второе место по доли платящих, хорошие показатели конверсии и окупаемости.
